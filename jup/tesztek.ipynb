# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/work_data/teljes_ms_google_tisztott.parquet')

# %%
df.head()
# Out:
#               gid           utca  cim telepules  iszam   orszag  \
# 0  47289911900891  Csalitos utca    6     Tököl   2316  Hungary
# 1  47290591901043   Diana sétány   55     Tököl   2316  Hungary
# 2  47289711900922   Diana sétány   71     Tököl   2316  Hungary
# 3  47290281900996   Diana sétány   61     Tököl   2316  Hungary
# 4  47283961900063   Diana sétány  147     Tököl   2316  Hungary
#
#                                             geometry
# 0  b'\x01\x01\x00\x00\x00\x17\x1eE\xe7F\x023@!\xd...
# 1  b'\x01\x01\x00\x00\x00\xbd3\x7f\xf1\xb1\x023@F...
# 2  b'\x01\x01\x00\x00\x00\x83.\xe1\xd0[\x023@\xd6...
# 3  b"\x01\x01\x00\x00\x00\xf8jGq\x8e\x023@\xb0eCH...
# 4  b'\x01\x01\x00\x00\x00\xc4\xd1\xb0s.\x003@\xbc...

# %%
df = pd.read_parquet('../data/work_data/osm_cim_kordinata.parquet')

# %%
df
# Out:
#                        id                                           geometry  \
# 0           node/16947670  b'\x01\x01\x00\x00\x00"u\x96\xb4=#2@\xd5\x98k,...
# 1           node/25546152  b'\x01\x01\x00\x00\x005B?S\xaf92@*\xca\x00\xab...
# 2           node/33123162  b'\x01\x01\x00\x00\x008;\x08\xf0\xcc\x8e1@L\xe...
# 3           node/33127897  b'\x01\x01\x00\x00\x00nP\xfb\xad\x9d\n2@p\x92\...
# 4           node/94743595  b'\x01\x01\x00\x00\x00\x9a\x8d\xdf%\x82N1@`P\x...
# ...                   ...                                                ...
# 681195  relation/19340426  b'\x01\x01\x00\x00\x00m"\xed8\x08\xa35@\x1e\x0...
# 681196  relation/19716998  b'\x01\x01\x00\x00\x00\xb5\xb7\x93\xdd\xb906@A...
# 681197  relation/20047599  b'\x01\x01\x00\x00\x00\xbaO\xa6\x9dP24@h\xc0h\...
# 681198  relation/20081016  b'\x01\x01\x00\x00\x00r\xa5\xc0\xc5\xf5\xab5@\...
# 681199  relation/20156689  b'\x01\x01\x00\x00\x00\x18\xfe\xf7ZN\x995@\xad...
#
# ...

# %%
df = pd.read_parquet('../data/work_data/osm_gmaps_merged.parquet')

# %%
df
# Out:
#                                                   geometry          city  \
# 0        b'\x01\x01\x00\x00\x00"u\x96\xb4=#2@\xd5\x98k,...          Orfű
# 1        b'\x01\x01\x00\x00\x005B?S\xaf92@*\xca\x00\xab...          Pécs
# 2        b'\x01\x01\x00\x00\x008;\x08\xf0\xcc\x8e1@L\xe...        Fonyód
# 3        b'\x01\x01\x00\x00\x00nP\xfb\xad\x9d\n2@p\x92\...           Tab
# 4        b'\x01\x01\x00\x00\x00\x9a\x8d\xdf%\x82N1@`P\x...    Somogyszob
# ...                                                    ...           ...
# 2511551  b'\x01\x01\x00\x00\x00\xe9z\xa2\xeb\xc2\xe33@8...         Atkár
# 2511552  b'\x01\x01\x00\x00\x00\xed:e\x7f\xea\x076@\x8d...         Dámóc
# 2511553  b'\x01\x01\x00\x00\x00\x91\x83m\x1fM\xc03@\xe8...   Kiskunmajsa
# 2511554  b'\x01\x01\x00\x00\x00x\x82X\x91,\x913@\xf1\xa...   Tápiószecső
# 2511555  b'\x01\x01\x00\x00\x00\xb32\xd0k\xa2\x9b4@}2\x...  Magyarcsanád
#
#         postcode                street housenumber source    color
# ...

# %%
df = pd.read_csv('../data/nyers_data/valasztas_cimek_2022.csv')

# %%
df[df['telepules_nev'].str.contains('Budapest')]
# Out:
#          szavazokor_id  utca_id            utca_nev      hazszam  \
# 1047           1600526  1332616       Nőegylet utca            2
# 1048           1600526  1332590      Kapisztrán tér  000002-0004
# 1049           1600526  1332590      Kapisztrán tér            1
# 1050           1600526  1332645  Szentháromság utca  000004-0006
# 1051           1600526  1332645  Szentháromság utca  000009-0011
# ...                ...      ...                 ...          ...
# 3449251        1610428  1331663       Muskétás utca            1
# 3449252        1610428  1331663       Muskétás utca            1
# 3449253        1610428  1331613       Kékperje utca            4
# 3449254        1610428  1331613       Kékperje utca            6
# 3449255        1610428  1331613       Kékperje utca            8
#
#          telepules_id         telepules_nev
# 1047              734   Budapest I. kerület
# 1048              734   Budapest I. kerület
# 1049              734   Budapest I. kerület
# ...

# %%
df.query('telepules_nev == "Sajószentpéter"')
# Out:
# Empty DataFrame
# Columns: [szavazokor_id, utca_id, utca_nev, hazszam, telepules_id, telepules_nev]
# Index: []

# %%
df[df['telepules_nev'].str.contains('Sajószentpéter')]
# Out:
# Empty DataFrame
# Columns: [szavazokor_id, utca_id, utca_nev, hazszam, telepules_id, telepules_nev]
# Index: []
