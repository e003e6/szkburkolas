# %%
import pandas as pd
import geopandas as gpd

# %%
gdf = gpd.read_file('../burkolas_v3/adatok/osszekapcsolt_pontok_es_cimek.gpkg')

# %%
gdf
# Out:
#          szavazokorid                utca hazszam telepules  \
# 0             1600517  Petőfi Sándor utca       1     Ibafa
# 1             1600517  Petőfi Sándor utca      10     Ibafa
# 2             1600517  Petőfi Sándor utca      11     Ibafa
# 3             1600517  Petőfi Sándor utca      12     Ibafa
# 4             1600517  Petőfi Sándor utca      14     Ibafa
# ...               ...                 ...     ...       ...
# 1568296       1610605         Lőrinc utca      14   Szentes
# 1568297       1610605          Farkas zug       2   Szentes
# 1568298       1610607           Kötő utca       1   Szentes
# 1568299       1610615     Bacsó Béla utca    9-13   Szentes
# 1568300       1610615     Bacsó Béla utca      15   Szentes
#
#                           geometry
# 0        POINT (17.91557 46.15492)
# 1        POINT (17.91403 46.15501)
# 2        POINT (17.91308 46.15513)
# 3        POINT (17.91349 46.15506)
# 4        POINT (17.91289 46.15508)
# ...

# %%
varosok = gdf['telepules'].unique().tolist()

# %%
len(varosok)
# Out:
# 2846

# %%
gdf.query('telepules == "12. kerület"')
# Out:
# Empty GeoDataFrame
# Columns: [szavazokorid, utca, hazszam, telepules, geometry]
# Index: []
