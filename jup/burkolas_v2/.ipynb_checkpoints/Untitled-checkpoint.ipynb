# %%
import pandas as pd
import geopandas as gpd

from adat_strukturalas import *

# %%
df = pd.read_csv('../../adatok/fix/ward_streetaddress.txt', sep='\t')
# Out:
# /var/folders/3_/cgvtrjw91kv4zf33d4_zxhz00000gn/T/ipykernel_6814/3459861740.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../adatok/fix/ward_streetaddress.txt', sep='\t')

# %%
df
# Out:
#           szavazokorid  kozteruletid  kozteruletnevid         kozteruletnev  \
# 0               228162     1423681.0          1562638          Szabadság út
# 1               228162     1430791.0          1569671               Béke út
# 2               228163     1360719.0          1500573          Templom utca
# 3               228163     1360719.0          1500574    Ságvári Endre utca
# 4               228163     1398292.0          1537590    Petőfi Sándor utca
# ...                ...           ...              ...                   ...
# 11802890       1610730     1346273.0          1489208  Mikszáth Kálmán utca
# 11802891       1610730     1346273.0          1489208  Mikszáth Kálmán utca
# 11802892       1610730     1346273.0          1489208  Mikszáth Kálmán utca
# 11802893       1610730     1346273.0          1489208  Mikszáth Kálmán utca
# 11802894       1610730     1346273.0          1489208  Mikszáth Kálmán utca
#
# ...
